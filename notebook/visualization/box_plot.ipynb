# %%
OUT_PATH = 'C:/Users/thmas/OneDrive - Universidad de Castilla-La Mancha/Informática/TFG/out/'
CONS_PATH = OUT_PATH + 'consumptions.zip'

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
df = pd.read_pickle(CONS_PATH)

df[['h' + str(i) for i in range(24)]] = df.apply(lambda x: x[-1], axis=1, result_type='expand')
da = df[(df['building_id'] == 27) & (df['active'])]
da = df.drop(['building_id', 'weekday', 'active', 'type', 'consumptions'], axis=1)
da
# Out:
#                    h0         h1         h2         h3         h4         h5  \
# day
# 2011-07-27  17.000000  19.000000  18.350795  35.846313  47.846263  50.846379
# 2011-07-28  18.888704  18.803009  18.845892  35.845713  47.845857  51.845696
# 2011-07-29  20.000000  21.000000  20.000000  37.788779  45.845705  50.845726
# 2011-07-30  17.298113  17.000000  17.239697  17.845833  17.914470  18.000000
# 2011-07-31  18.845599  17.153853  18.000000  18.000000  18.000000  20.000000
# ...               ...        ...        ...        ...        ...        ...
# 2020-05-09   9.501061   8.969314   8.601893   9.177339   9.249469   9.197714
# 2020-05-11   8.571664  10.306219  10.459674  12.972392  11.765655  11.724973
# 2020-05-12   8.315693   9.214115  10.190292  12.968106  13.748632  16.590447
# 2020-05-13   8.719203   9.094131  10.023078  11.231253  10.366276  16.438414
# 2020-05-14  13.640756  10.161902  10.165417  11.567294  10.971040  12.740922
#
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

da.plot(kind='box', figsize=(12,10), ax=ax)
da.mean().plot(ax=ax, color='red')

# %%
da.hist(figsize=(10,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E005C7F60>,
# ...
#       dtype=object)
